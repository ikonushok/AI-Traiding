# %% [markdown]
# ## Install & Imports

# %%
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr 
import matplotlib.pyplot as plt

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore")

# %%
#!pip install yfinance
#!conda install -c ranaroussi yfinance --y
import yfinance as yf # requires yfinance - pip install yfinance

# %%
# !curl --remote-name --location https://raw.githubusercontent.com/chekh/ai_tr_libs/main/Long_n_short_strategy.py
# !curl --remote-name --location https://raw.githubusercontent.com/chekh/ai_tr_libs/main/Long_strategy.py
clear_output()
    
# Библиотеки из ai_tr_libs
from Long_n_short_strategy import Long_n_Short_Strategy as LnS
from Long_strategy import Long_Strategy as LS
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# !pip install backtesting
clear_output()

# Библиоетки backtesting
from backtesting import Backtest, Strategy

# %% [markdown]
# # 1h: counter_lvl = 8

# %% [markdown]
# ## Загружаем данные

# %%
# загружаем класс скачивания данных с ФИНАМа
#from dataloader import Dataloader as dl

# Используем класс dataloader (dl) для загрузки данных с Финам
#df = dl('POLY', start_date='01-01-2018', save_to_file=False, capitalize=True).get_data()
#df

# %%
# Начните с активации обходного пути Yahoo Finance и установки начальной и конечной точек фрейма данных.
# здесь Yf.pdr_override () активирует ваши условия обходного пути, а остальное установит ваш фрейм данных.
yf.pdr_override()
start = dt.datetime(2020,1, 1)
now = dt.datetime.now()
interval = '1h' # interval=60min is not supported. Valid intervals: [1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
stock = 'POLY.ME'

buy_signals = pd.DataFrame() # dataframe для записи сигналов
sell_signals = pd.DataFrame() # dataframe для записи сигналов

# %%
df = pdr.get_data_yahoo(stock,
                        start,
                        now,
                        interval = interval)

del df['Adj Close'], df['Volume']
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close
# Date
# 2020-01-03   978.400024   980.000000   967.099976   976.200012
# 2020-01-03   976.000000   984.599976   973.099976   982.500000
# 2020-01-03   983.000000   983.099976   980.299988   981.200012
# 2020-01-03   981.700012   984.000000   980.200012   982.200012
# 2020-01-03   983.000000   988.599976   982.799988   986.400024
# ...                 ...          ...          ...          ...
# 2021-05-21  1790.599976  1794.000000  1787.699951  1793.000000
# 2021-05-21  1793.400024  1801.000000  1793.400024  1797.900024
# 2021-05-21  1798.000000  1801.500000  1784.000000  1784.000000
# 2021-05-21  1784.099976  1792.800049  1770.400024  1777.000000
# 2021-05-21  1776.599976  1776.599976  1776.599976  1776.599976
#
# [3459 rows x 4 columns]

# %% [markdown]
# ## Разметка Y

# %%
from markup_y import SELL, BUY

# %%
sell_signals = SELL(df, counter_lvl = 8)
sell_signals = sell_signals.set_index('Date')
sell_signals
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b1cf69134a5f> in <module>
# ----> 1 sell_signals = SELL(df, counter_lvl = 8)
#       2 sell_signals = sell_signals.set_index('Date')
#       3 sell_signals
#
# ~/PycharmProjects/AI-Traiding/The basics of using neural networks in trading/Notebooks/markup_y.py in SELL(data, counter_lvl)
#      33         daterange.append(i)
#      34
# ---> 35         if currentMax == max(Range , default=0):
#      36             counter+=1
#      37         else:
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1441     def __nonzero__(self):
#    1442         raise ValueError(
# -> 1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1445         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
buy_signals = BUY(df, counter_lvl = 8)
buy_signals = buy_signals.set_index('Date')
buy_signals

# %% [markdown]
# ## Обьединение датафреймов

# %%
signals = sell_signals.append(buy_signals)
df_new = df

df_new = pd.merge(df_new, signals['Signal'], on=('Date'), how ='left')
df_new = df_new.fillna(0)
df_new.loc[df_new['Signal'] != 0]

# %% [markdown]
# ## График торговли

# %% [markdown]
# ### Long

# %%
# Стратегия Long & Short (подключен класс стратегии LnS)
bt = Backtest(df_new, LS, cash=100000, commission=.004, trade_on_close=True)
stats = bt.run()
bt.plot(plot_volume=True, relative_equity=True)

# %%
stats

# %% [markdown]
# ### Long & Short

# %%
# Стратегия Long & Short (подключен класс стратегии LnS)
bt = Backtest(df_new, LnS, cash=100000, commission=.004, trade_on_close=True)
stats = bt.run()
bt.plot(plot_volume=True, relative_equity=True)

# %%
stats

# %% [markdown]
# # 1h: Подбор оптимального counter_lvl

# %%
LnS_results = pd.DataFrame() # dataframe для записи результатов подбора оптимального окна counter_lvl

for i in range(2, 9):
    
    # Разметим Y
    sell_signals = SELL(df, counter_lvl = i)
    sell_signals = sell_signals.set_index('Date')
    buy_signals = BUY(df, counter_lvl = i)
    buy_signals = buy_signals.set_index('Date')
    
    # Обьединим датафреймы
    signals = sell_signals.append(buy_signals)
    df_new = df

    df_new = pd.merge(df_new, signals['Signal'], on=('Date'), how ='left')
    df_new = df_new.fillna(0)
    df_new.loc[df_new['Signal'] != 0]
    
    # Backtesting
    # Стратегия Long & Short (подключен класс стратегии LnS)
    bt = Backtest(df_new, LnS, cash=100000, commission=.004, trade_on_close=True)
    stats = bt.run()
    
    print('counter_lvl =', i, '\n', stats[6:15])
    print('='*100)
    print()
    
    line = pd.DataFrame({'counter_lvl':[i],
                         'Trades':[stats[17]],
                         'Return [%]':[stats[6]],
                         'Buy & Hold Return [%]':[stats[7]],
                         'Return (Ann.) [%]':[stats[8]],
                         'Sharpe Ratio':[stats[10]],
                         'Sortino Ratio':[stats[11]],
                         'Calmar Ratio':[stats[12]],
                         'Max. Drawdown [%]':[stats[13]],
                         'Avg. Drawdown [%]]':[stats[14]],
                         'Win Rate [%]':[stats[18]]
                        })
    LnS_results = LnS_results.append(line, ignore_index=True)

# %%
LnS_results
